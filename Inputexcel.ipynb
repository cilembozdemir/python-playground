# %%
import pandas as pd

# %%
import numpy as np
import csv

# %%
data = pd.read_csv('mtcars.csv', usecols=[1,3])

# %%
print(data)
# Out:
#      mpg   disp
# 0   21.0  160.0
# 1   21.0  160.0
# 2   22.8  108.0
# 3   21.4  258.0
# 4   18.7  360.0
# 5   18.1  225.0
# 6   14.3  360.0
# 7   24.4  146.7
# 8   22.8  140.8
# 9   19.2  167.6
# 10  17.8  167.6
# 11  16.4  275.8
# 12  17.3  275.8
# 13  15.2  275.8
# 14  10.4  472.0
# 15  10.4  460.0
# 16  14.7  440.0
# 17  32.4   78.7
# 18  30.4   75.7
# 19  33.9   71.1
# 20  21.5  120.1
# 21  15.5  318.0
# 22  15.2  304.0
# 23  13.3  350.0
# 24  19.2  400.0
# 25  27.3   79.0
# 26  26.0  120.3
# 27  30.4   95.1
# 28  15.8  351.0
# 29  19.7  145.0
# 30  15.0  301.0
# 31  21.4  121.0

# %%
data.plot.bar(rot=1)

# %%
print(df)

# %% [markdown]
# data['date'] = pd.date_range(start='1/1/1979', periods=len(df), freq='D')
